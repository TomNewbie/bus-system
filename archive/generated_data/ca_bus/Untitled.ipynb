# %%
import pandas as pd


df = pd.read_csv('merged.csv')

# %%
df
# Out:
#                                  shape_id  \
# 0    025e3cd3-af74-42bc-89a7-cc35ee83bd10
# 1    1367bd0e-b38f-442d-8c9d-6c07d22eb8fd
# 2    1367bd0e-b38f-442d-8c9d-6c07d22eb8fd
# 3    25577955-0808-4cc2-a0e4-c16dd501b22f
# 4    25577955-0808-4cc2-a0e4-c16dd501b22f
# ..                                    ...
# 151  e14372ae-afae-4f2f-ba56-051217c3c770
# 152  f01e8e5e-90a0-4047-b80b-90c4520caa80
# 153  f01e8e5e-90a0-4047-b80b-90c4520caa80
# 154  f01e8e5e-90a0-4047-b80b-90c4520caa80
# 155  f01e8e5e-90a0-4047-b80b-90c4520caa80
#
#                                  route_id  direction_id  stop_sequence  \
# 0    db26052a-916e-4235-9caa-0a364b781f39             0             52
# 1    323165ef-99ee-4955-801e-553bcb415229             0              2
# 2    323165ef-99ee-4955-801e-553bcb415229             0              2
# 3    605702ef-34fb-4f95-bc52-25022968f4af             0            167
# 4    605702ef-34fb-4f95-bc52-25022968f4af             0            167
# ...

# %%
import matplotlib.pyplot as plt


window_counts = df['window'].value_counts()

# Plot the bar chart
plt.bar(window_counts.index, window_counts.values)
plt.xlabel('Window')
plt.ylabel('Frequency')
plt.title('Distribution of Windows')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import numpy as np

# Assuming your CSV file is named 'your_file.csv'
df = pd.read_csv('merged.csv')

# Assuming 'speed_kmh' is the target variable (you can change it based on your specific prediction goal)
target_variable = 'speed_kmh'

# Selecting relevant features for prediction
features = df[['stop_sequence', 'avg_route_speed_kmh', 'segment_max_speed_kmh']]

# Splitting the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, df[target_variable], test_size=0.2, random_state=42)

# Creating a linear regression model
model = LinearRegression()

# Training the model
model.fit(X_train, y_train)

# Making predictions on the test set
y_pred = model.predict(X_test)

# Evaluating the model
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')

# Example: Predicting congestion for a new data point
new_data_point = np.array([[52, 1135.0, 1135.0]])  # Replace with actual values
prediction = model.predict(new_data_point)
print(f'Predicted Congestion Level: {prediction[0]}')
# Out:
# Mean Squared Error: 129604.77983323683
# Predicted Congestion Level: 965.9657637941492
# C:\Users\vinhn\.conda\envs\tf_cpu\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
